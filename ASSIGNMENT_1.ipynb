# %%
import pandas as pd
File1=pd.read_excel("/content/vignesh.xlsx")
File1
# Out:
#    SN     Name gender nationality organisation  work experinece
# 0   1  vignesh      m      indian          jio                3
# 1   2    raghu      m     amrican    angel one                6
# 2   3    vinay      m      africa       google                4
# 3   4    rahul      m    pakistan        tesla                6
# 4   5  avinash      m      indian       infoys                5

# %%
import pandas as pd
File2=pd.read_table("/content/vignesh.txt")
File2
# Out:
#    SN     Name gender nationality organisation  work experinece
# 0   1  vignesh      m      indian          jio                3
# 1   2    raghu      m     amrican    angel one                6
# 2   3    vinay      m      africa       google                4
# 3   4    rahul      m    pakistan        tesla                6
# 4   5  avinash      m      indian       infoys                5

# %%
import pandas as pd
File3=pd.read_csv("/content/vignesh.csv")
File3
# Out:
#    SN     Name gender nationality organisation  work experinece
# 0   1  vignesh      m      indian          jio                3
# 1   2    raghu      m     amrican    angel one                6
# 2   3    vinay      m      africa       google                4
# 3   4    rahul      m    pakistan        tesla                6
# 4   5  avinash      m      indian       infoys                5
